# %%
import dlib
import cv2
from google.colab.patches import cv2_imshow

# %%
#detector
detektor = dlib.get_frontal_face_detector()

# %%
#load gambar
frame = cv2.imread("alisa.jpeg", cv2.IMREAD_COLOR)

# %%
#flip
frame = cv2.flip(frame, 1)

# %%
#gray_scaling
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
face = detektor(gray)
# Out:
# <PIL.Image.Image image mode=L size=720x1280 at 0x7F5AA888D6D0>

# %%
i=0
for face in face:
  x, y = face.left(), face.top()
  x1, y1 = face.right(), face.bottom()
  cv2.rectangle(frame, (x,y), (x1,y1), (0,255,0), 2)
  i = i+1

  cv2.putText(frame, 'wajah ke'+str(i), (x-10, y-10),
              cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
  print(face, i)

cv2_imshow(frame)
# Out:
# [(480, 176) (604, 300)] 1
# [(189, 328) (314, 452)] 2
# [(507, 397) (632, 521)] 3
# <PIL.Image.Image image mode=RGB size=720x1280 at 0x7F5AA681DDD0>
